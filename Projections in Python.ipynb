# %%
cd /Users/corcoran/Downloads
# Out:
# /Users/corcoran/Downloads

# %%
from astropy.table import Table
dat=Table.read('BrowseTargets.26351.1396367134',format="ascii")

# %%
dat
# Out:
# <Table rows=500 names=('col0','name','count_rate','count_rate_error','flux','database_table','observatory','lii','bii','col9')>
# masked_array(data = [(--, 'XTE SMC144s', --, --, --, 'MAGHMXBCAT', --, --, --, --)
#  (--, '1RXS J093436.5-891243', 0.02444, 0.01166, --, 'RASSFSC', 'ROSAT', 302.26472, -26.61191, --)
#  (--, '2MAXI J2213-891', --, --, 5.7e-12, 'MAXIGSCHGL', 'MAXI', 303.50759, -27.74385, --)
#  (--, '1RXS J222825.9-891045', 0.01931, 0.009216, --, 'RASSFSC', 'ROSAT', 303.47404, -27.79336, --)
#  (--, '1RXS J072827.7-890320', 0.02801, 0.01194, --, 'RASSFSC', 'ROSAT', 301.88599, -26.97247, --)
#  (--, '1RXS J091746.5-890303', 0.02418, 0.01082, --, 'RASSFSC', 'ROSAT', 302.07996, -26.56006, --)
#  (--, '1RXS J105047.2-885952', 0.1038, 0.02218, --, 'RASSBSC', 'ROSAT', 302.37041, -26.26062, --)
#  (--, '1RXS J105047.2-885952', 0.1, 0.02, --, 'RASS2MASS', 'ROSAT', 302.37041, -26.26061, --)
# ...

# %%
dat.columns
# Out:
# <TableColumns names=('col0','name','count_rate','count_rate_error','flux','database_table','observatory','lii','bii','col9')>

# %%
c
# Out:
# ['col0',
#  'name',
#  'count_rate',
#  'count_rate_error',
#  'flux',
#  'database_table',
#  'observatory',
#  'lii',
#  'bii',
#  'col9']

# %%
l=dat['lii']
b=dat['bii']

# %%
plot(b,l,'ro')

# %%
fig = plt.figure(figsize=plt.figaspect(0.75))
subplot(212, projection='aitoff', )
deg2rad = pi/180.
plot(l,b, 'ro')
grid(True)
text(0,-120*deg2rad,'Galactic longitude (degrees)',ha='center', va='center')
ylabel('Galactic latitude (degrees)')
show()

# %%
bdeg2rad
# Out:
# <MaskedColumn name=None unit=None format=None description=None>
# masked_array(data = [-- -0.46446544974440424 -0.4842215296794288 -0.4850856421920912
#  -0.47075840889539494 -0.4635604965272451 -0.4583342826150733
#  -0.4583341080821481 -0.4873961090558813 -0.45579151242784277
#  -0.4855228471697158 -0.4539391944927012 -0.4782661172057737
#  -0.4641914330518411 -0.46413837504258043 -0.46413837504258043
#  -0.46744804290313735 -0.46744804290313735 -0.4674469957055861
#  -0.46419125851891585 -0.4507808466782922 -0.4507784032173395
#  -0.4668178045102422 -0.49624283396839014 -0.46860781419108755
#  -0.4686076396581624 -0.484471111762464 -0.49578189251293847
#  -0.477642336531111 -0.46993600975185523 -0.4512784400480358
#  -0.4967365876137793 -0.4667113394258705 -0.4944673105203363
#  -0.4984690014293089 -0.4875346881984896 -0.4891492922895096
#  -0.49708984225438296 -0.46244697646447275 -0.5037292492618947
#  -0.48477410092061024 -0.4760359354875754 -0.48349529817767395
# ...

# %%
from astropy.vo.client import conesearch
from astropy import coordinates as coord
from astropy import units as u

# %%
c = coord.ICRSCoordinates.from_name('M31')
conesearch.list_catalogs()
# Out:
# [u'Guide Star Catalog 2.3 1',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 1',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 2',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 3',
#  u'SDSS DR7 - Sloan Digital Sky Survey Data Release 7 4',
#  u'The HST Guide Star Catalog, Version 1.1 (Lasker+ 1992) 1',
#  u'The HST Guide Star Catalog, Version 1.2 (Lasker+ 1996) 1',
#  u'The HST Guide Star Catalog, Version GSC-ACT (Lasker+ 1996-99) 1',
#  u'The PMM USNO-A1.0 Catalogue (Monet 1997) 1',
#  u'The USNO-A2.0 Catalogue (Monet+ 1998) 1',
#  u'Two Micron All Sky Survey (2MASS) 1',
#  u'Two Micron All Sky Survey (2MASS) 2',
#  u'USNO-A2 Catalogue 1',
#  u'USNO-A2.0 1']

# %%
c
# Out:
# <ICRS RA=10.68471 deg, Dec=41.26875 deg>

# %%
result = conesearch.conesearch(c, 0.1 * u.degree, catalog_db='Two Micron All Sky Survey (2MASS) 2')
# Out:
# Trying http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_xsc&
# ...
#  [Done]
# WARNING: W50: http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_xsc&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:24:0: W50: Invalid unit string 'Julian days' [astropy.io.votable.exceptions]
# WARNING: W06: http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_xsc&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:27:0: W06: Invalid UCD '??': UCD has invalid character '?' in '??' [astropy.io.votable.exceptions]
# WARNING
# : W06: http://wfaudata.roe.ac.uk/twomass-dsa/DirectCone?DSACAT=TWOMASS&DSATAB=twomass_xsc&SR=0.1&DEC=41.26875&RA=10.6847083&VERB=1:1065:0: W06: Invalid UCD '??': UCD has invalid character '?' in '??' [astropy.io.votable.exceptions]
# ...

# %%
result

# %%
tab=result.to_table()

# %%
tab
# Out:
# <Table rows=25 names=('cx','cy','cz','htmID','jdate','designation','ra','dec','sup_ra','sup_dec','glon','glat','density','r_k20fe','j_m_k20fe','j_msig_k20fe','j_flg_k20fe','h_m_k20fe','h_msig_k20fe','h_flg_k20fe','k_m_k20fe','k_msig_k20fe','k_flg_k20fe','r_3sig','j_ba','j_phi','h_ba','h_phi','k_ba','k_phi','sup_r_3sig','sup_ba','sup_phi','r_fe','j_m_fe','j_msig_fe','j_flg_fe','h_m_fe','h_msig_fe','h_flg_fe','k_m_fe','k_msig_fe','k_flg_fe','r_ext','j_m_ext','j_msig_ext','j_pchi','h_m_ext','h_msig_ext','h_pchi','k_m_ext','k_msig_ext','k_pchi','j_r_eff','j_mnsurfb_eff','h_r_eff','h_mnsurfb_eff','k_r_eff','k_mnsurfb_eff','j_con_indx','h_con_indx','k_con_indx','j_peak','h_peak','k_peak','j_5surf','h_5surf','k_5surf','e_score','g_score','vc','cc_flg','im_nx','r_k20fc','j_m_k20fc','j_msig_k20fc','j_flg_k20fc','h_m_k20fc','h_msig_k20fc','h_flg_k20fc','k_m_k20fc','k_msig_k20fc','k_flg_k20fc','j_r_e','j_m_e','j_msig_e','j_flg_e','h_r_e','h_m_e','h_msig_e','h_flg_e','k_r_e','k_m_e','k_msig_e','
# ...
